# %% [markdown]
# # Baseline portfolio
#
# Compare EUR cash, buy-and-hold assets, and simple static portfolios after realistic costs.
#
# This notebook is a scaffold. Its data sources, assumptions, and evaluation protocol must be recorded before analysis.
